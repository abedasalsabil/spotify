# %%
# Import the modules
import pandas as pd
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import findspark
findspark.init()
from pyspark.sql import SparkSession
import seaborn as sns

# %%
# Read in the CSV file and create the Pandas DataFrame
df_spotify_May = pd.read_csv(
    Path("Resources/May_tracks_metadata.csv")
)

# Review the DataFrame
df_spotify_May.head()
# Out:
#    Unnamed: 0          track.album.id      track.album.name  \
# 0           0  4Z1NyCGQaXlJahP9qm01bG  #Sarkanbaltsarkanais
# 1           1  4b65l6XzLp2Eg6lDTMmO1k               #osnrap
# 2           2  2WFFcvzM0CgLaSq4MSkyZk            - (Deluxe)
# 3           3  2WFFcvzM0CgLaSq4MSkyZk            - (Deluxe)
# 4           4  2WFFcvzM0CgLaSq4MSkyZk            - (Deluxe)
#
#                  track.id            track.name track.album.album_type  \
# 0  3bY8hZbtWQpCOGHi1IZvz5  #Sarkanbaltsarkanais                 single
# 1  0KWnRv3wxjltYVB3MqjNd2           Without You                  album
# 2  6jemILri7l5LuPhKs2nuXr                  Boat                  album
# 3  6ZZf5a8oiInHDkBe9zXfLP              Curtains                  album
# 4  4u4A4lPpiw54evLxTaLeRJ                 Dusty                  album
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 1  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 2  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 3  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 4  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
#
#                    track.album.external_urls.spotify  \
# 0  https://open.spotify.com/album/4Z1NyCGQaXlJahP...
# 1  https://open.spotify.com/album/4b65l6XzLp2Eg6l...
# 2  https://open.spotify.com/album/2WFFcvzM0CgLaSq...
# 3  https://open.spotify.com/album/2WFFcvzM0CgLaSq...
# 4  https://open.spotify.com/album/2WFFcvzM0CgLaSq...
#
#                                     track.album.href  ... danceability energy  \
# 0  https://api.spotify.com/v1/albums/4Z1NyCGQaXlJ...  ...        0.738  0.785
# 1  https://api.spotify.com/v1/albums/4b65l6XzLp2E...  ...        0.669  0.698
# 2  https://api.spotify.com/v1/albums/2WFFcvzM0CgL...  ...        0.470  0.203
# 3  https://api.spotify.com/v1/albums/2WFFcvzM0CgL...  ...        0.500  0.757
# 4  https://api.spotify.com/v1/albums/2WFFcvzM0CgL...  ...        0.711  0.550
#
#   key  loudness speechiness acousticness instrumentalness liveness  valence  \
# 0  11    -5.003      0.1040       0.0608         0.000000    0.403    0.626
# 1  11    -4.613      0.0910       0.5730         0.000000    0.102    0.286
# 2   4    -8.676      0.0371       0.7580         0.000002    0.312    0.325
# 3   6    -6.542      0.0522       0.0989         0.000003    0.324    0.443
# 4   2    -9.682      0.0332       0.2260         0.009280    0.120    0.616
#
#      tempo
# 0  110.118
# 1   80.003
# 2  153.578
# 3  175.944
# 4  146.928
#
# [5 rows x 43 columns]

# %%
df = df_spotify_May[['track.album.name','track.name','track.album.album_type',
                       'track.album.artists','track.popularity','danceability',
                      'energy', 'key', 'loudness','speechiness', 'acousticness', 
                      'instrumentalness', 'liveness', 'valence', 'tempo']].copy()
df
# Out:
#            track.album.name             track.name track.album.album_type  \
# 0      #Sarkanbaltsarkanais   #Sarkanbaltsarkanais                 single
# 1                   #osnrap            Without You                  album
# 2                - (Deluxe)                   Boat                  album
# 3                - (Deluxe)               Curtains                  album
# 4                - (Deluxe)                  Dusty                  album
# ...                     ...                    ...                    ...
# 3056                關掉 / 打開                   我就想你                  album
# 3057                  隱形遊樂場                  隱形遊樂場                 single
# 3058                    青と夏                   点描の唄                 single
# 3059            青春のエキサイトメント              愛を伝えたいだとか                  album
# 3060  風雨不改 (電影《阿媽有咗第二個》主題曲)  風雨不改 (電影《阿媽有咗第二個》主題曲)                 single
#
#                                     track.album.artists  track.popularity  \
# 0     [{'external_urls': {'spotify': 'https://open.s...              38.0
# 1     [{'external_urls': {'spotify': 'https://open.s...              65.0
# 2     [{'external_urls': {'spotify': 'https://open.s...              75.0
# 3     [{'external_urls': {'spotify': 'https://open.s...              83.0
# 4     [{'external_urls': {'spotify': 'https://open.s...              65.0
# ...                                                 ...               ...
# 3056  [{'external_urls': {'spotify': 'https://open.s...              64.0
# 3057  [{'external_urls': {'spotify': 'https://open.s...              62.0
# 3058  [{'external_urls': {'spotify': 'https://open.s...              74.0
# 3059  [{'external_urls': {'spotify': 'https://open.s...              69.0
# 3060  [{'external_urls': {'spotify': 'https://open.s...              70.0
#
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.738   0.785   11    -5.003       0.1040        0.0608
# 1            0.669   0.698   11    -4.613       0.0910        0.5730
# 2            0.470   0.203    4    -8.676       0.0371        0.7580
# 3            0.500   0.757    6    -6.542       0.0522        0.0989
# 4            0.711   0.550    2    -9.682       0.0332        0.2260
# ...            ...     ...  ...       ...          ...           ...
# 3056         0.501   0.462    7    -7.102       0.0726        0.1860
# 3057         0.485   0.452    7    -7.212       0.0379        0.4360
# 3058         0.502   0.632    0    -4.612       0.0273        0.4470
# 3059         0.673   0.850    2    -5.021       0.0337        0.0345
# 3060         0.319   0.198    0   -11.611       0.0402        0.9420
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000000    0.4030    0.626  110.118
# 1             0.000000    0.1020    0.286   80.003
# 2             0.000002    0.3120    0.325  153.578
# 3             0.000003    0.3240    0.443  175.944
# 4             0.009280    0.1200    0.616  146.928
# ...                ...       ...      ...      ...
# 3056          0.000000    0.4180    0.585   82.513
# 3057          0.000007    0.1960    0.158  133.517
# 3058          0.000000    0.1030    0.308  152.014
# 3059          0.000011    0.0943    0.793  100.008
# 3060          0.000009    0.0817    0.287   62.925
#
# [3061 rows x 15 columns]

# %%
df[df['track.name'].duplicated()]
# Out:
#                     track.album.name                      track.name  \
# 118                            ALPHA                  Jena Mbreter 2
# 164                            Ajini                           Ajini
# 177                    Almost Healed     All My Life (feat. J. Cole)
# 356   Besharam Rang (From "Pathaan")  Besharam Rang (From "Pathaan")
# 464                  Ceramics Runway                              17
# ...                              ...                             ...
# 3025                              瓦合                               但
# 3026                              瓦合                               但
# 3030                              瓦合                               床
# 3031                              瓦合                               床
# 3042                            美しい鰭                            美しい鰭
#
#      track.album.album_type  \
# 118                   album
# 164                  single
# 177                   album
# 356                  single
# 464                   album
# ...                     ...
# 3025                 single
# 3026                  album
# 3030                 single
# 3031                  album
# 3042                 single
#
#                                     track.album.artists  track.popularity  \
# 118   [{'external_urls': {'spotify': 'https://open.s...              49.0
# 164   [{'external_urls': {'spotify': 'https://open.s...              49.0
# 177   [{'external_urls': {'spotify': 'https://open.s...              79.0
# 356   [{'external_urls': {'spotify': 'https://open.s...              82.0
# 464   [{'external_urls': {'spotify': 'https://open.s...              62.0
# ...                                                 ...               ...
# 3025  [{'external_urls': {'spotify': 'https://open.s...              48.0
# 3026  [{'external_urls': {'spotify': 'https://open.s...              58.0
# 3030  [{'external_urls': {'spotify': 'https://open.s...              57.0
# 3031  [{'external_urls': {'spotify': 'https://open.s...              60.0
# 3042  [{'external_urls': {'spotify': 'https://open.s...              78.0
#
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 118          0.775   0.838   11    -4.092       0.0889       0.32900
# 164          0.776   0.625    2    -8.946       0.0845       0.23600
# 177          0.787   0.570    3    -5.881       0.2250       0.04490
# 356          0.773   0.795    8    -5.537       0.0412       0.05870
# 464          0.748   0.777   10    -4.783       0.0430       0.04710
# ...            ...     ...  ...       ...          ...           ...
# 3025         0.606   0.484    2    -6.497       0.0376       0.00615
# 3026         0.606   0.484    2    -6.497       0.0376       0.00615
# 3030         0.660   0.768    7    -7.187       0.0313       0.04410
# 3031         0.660   0.768    7    -7.187       0.0313       0.04410
# 3042         0.551   0.909    1    -3.711       0.0295       0.01010
#
#       instrumentalness  liveness  valence    tempo
# 118           0.000000    0.0354    0.588   89.929
# 164           0.000021    0.0680    0.505   98.032
# 177           0.000000    0.1350    0.733  142.974
# 356           0.002370    0.1540    0.649  115.997
# 464           0.004260    0.1260    0.970  121.034
# ...                ...       ...      ...      ...
# 3025          0.000129    0.1030    0.228   95.977
# 3026          0.000129    0.1030    0.228   95.977
# 3030          0.267000    0.0668    0.356  120.027
# 3031          0.267000    0.0668    0.356  120.027
# 3042          0.000313    0.2040    0.760   98.048
#
# [99 rows x 15 columns]

# %%
df[df['track.name']=='Jena Mbreter 2']
# Out:
#     track.album.name      track.name track.album.album_type  \
# 117            ALPHA  Jena Mbreter 2                  album
# 118            ALPHA  Jena Mbreter 2                  album
#
#                                    track.album.artists  track.popularity  \
# 117  [{'external_urls': {'spotify': 'https://open.s...              56.0
# 118  [{'external_urls': {'spotify': 'https://open.s...              49.0
#
#      danceability  energy  key  loudness  speechiness  acousticness  \
# 117         0.775   0.838   11    -4.092       0.0889         0.329
# 118         0.775   0.838   11    -4.092       0.0889         0.329
#
#      instrumentalness  liveness  valence   tempo
# 117               0.0    0.0354    0.588  89.929
# 118               0.0    0.0354    0.588  89.929

# %%
# Grouping by track_id number to get rid of duplicates and keeping the maximum values in each column.
df=df.groupby(['track.name']).max()

# %%
# Ensuring that the duplicates have been eliminated
df
# Out:
#                                     track.album.name track.album.album_type  \
# track.name
# #Sarkanbaltsarkanais            #Sarkanbaltsarkanais                 single
# 'Til We Meet Again     MY WORLD - The 3rd Mini Album                 single
# 00:00                                          00:00                 single
# 0321                                            0321                 single
# 085 - Ao Vivo                     Pode Crê (Ao Vivo)                  album
# ...                                              ...                    ...
# 雪 Distance                            Uniconfication                  album
# 青と夏                                         Attitude                  album
# 風雨不改 (電影《阿媽有咗第二個》主題曲)          風雨不改 (電影《阿媽有咗第二個》主題曲)                 single
# 飞鸟和蝉                                            Ren然                  album
# 麻克與林送夫                        大嘻哈時代2: DISS BACK 加倍奉還            compilation
#
#                                                      track.album.artists  \
# track.name
# #Sarkanbaltsarkanais   [{'external_urls': {'spotify': 'https://open.s...
# 'Til We Meet Again     [{'external_urls': {'spotify': 'https://open.s...
# 00:00                  [{'external_urls': {'spotify': 'https://open.s...
# 0321                   [{'external_urls': {'spotify': 'https://open.s...
# 085 - Ao Vivo          [{'external_urls': {'spotify': 'https://open.s...
# ...                                                                  ...
# 雪 Distance             [{'external_urls': {'spotify': 'https://open.s...
# 青と夏                    [{'external_urls': {'spotify': 'https://open.s...
# 風雨不改 (電影《阿媽有咗第二個》主題曲)  [{'external_urls': {'spotify': 'https://open.s...
# 飞鸟和蝉                   [{'external_urls': {'spotify': 'https://open.s...
# 麻克與林送夫                 [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.popularity  danceability  energy  key  loudness  \
# track.name
# #Sarkanbaltsarkanais               38.0         0.738   0.785   11    -5.003
# 'Til We Meet Again                 63.0         0.474   0.857    5    -2.577
# 00:00                              60.0         0.563   0.572    4    -8.769
# 0321                               67.0         0.658   0.417    2    -6.485
# 085 - Ao Vivo                      83.0         0.850   0.655    2    -2.891
# ...                                 ...           ...     ...  ...       ...
# 雪 Distance                         68.0         0.592   0.284    1    -9.398
# 青と夏                                71.0         0.310   0.891    4    -1.660
# 風雨不改 (電影《阿媽有咗第二個》主題曲)              70.0         0.319   0.198    0   -11.611
# 飞鸟和蝉                               67.0         0.578   0.508   10    -8.884
# 麻克與林送夫                             62.0         0.834   0.480    9    -8.529
#
#                        speechiness  acousticness  instrumentalness  liveness  \
# track.name
# #Sarkanbaltsarkanais        0.1040       0.06080          0.000000    0.4030
# 'Til We Meet Again          0.0571       0.13400          0.000000    0.1130
# 00:00                       0.1250       0.64000          0.002270    0.1000
# 0321                        0.0366       0.62500          0.000000    0.1320
# 085 - Ao Vivo               0.0298       0.21100          0.000000    0.9520
# ...                            ...           ...               ...       ...
# 雪 Distance                  0.0319       0.73900          0.000001    0.1730
# 青と夏                         0.0469       0.00157          0.000000    0.2840
# 風雨不改 (電影《阿媽有咗第二個》主題曲)       0.0402       0.94200          0.000009    0.0817
# 飞鸟和蝉                        0.0536       0.72200          0.000000    0.1050
# 麻克與林送夫                      0.0639       0.22400          0.000000    0.1390
#
#                        valence    tempo
# track.name
# #Sarkanbaltsarkanais    0.6260  110.118
# 'Til We Meet Again      0.5520  155.710
# 00:00                   0.3920   95.013
# 0321                    0.0748  171.974
# 085 - Ao Vivo           0.7970  106.031
# ...                        ...      ...
# 雪 Distance              0.6710   99.827
# 青と夏                     0.7480  184.886
# 風雨不改 (電影《阿媽有咗第二個》主題曲)   0.2870   62.925
# 飞鸟和蝉                    0.3040  147.940
# 麻克與林送夫                  0.4980  122.912
#
# [2962 rows x 14 columns]

# %%
df['artist'] = df['track.album.artists'].str.extract(r"'name': '(.+?)'")
df.drop('track.album.artists', axis=1, inplace=True)
df
# Out:
#                                     track.album.name track.album.album_type  \
# track.name
# #Sarkanbaltsarkanais            #Sarkanbaltsarkanais                 single
# 'Til We Meet Again     MY WORLD - The 3rd Mini Album                 single
# 00:00                                          00:00                 single
# 0321                                            0321                 single
# 085 - Ao Vivo                     Pode Crê (Ao Vivo)                  album
# ...                                              ...                    ...
# 雪 Distance                            Uniconfication                  album
# 青と夏                                         Attitude                  album
# 風雨不改 (電影《阿媽有咗第二個》主題曲)          風雨不改 (電影《阿媽有咗第二個》主題曲)                 single
# 飞鸟和蝉                                            Ren然                  album
# 麻克與林送夫                        大嘻哈時代2: DISS BACK 加倍奉還            compilation
#
#                        track.popularity  danceability  energy  key  loudness  \
# track.name
# #Sarkanbaltsarkanais               38.0         0.738   0.785   11    -5.003
# 'Til We Meet Again                 63.0         0.474   0.857    5    -2.577
# 00:00                              60.0         0.563   0.572    4    -8.769
# 0321                               67.0         0.658   0.417    2    -6.485
# 085 - Ao Vivo                      83.0         0.850   0.655    2    -2.891
# ...                                 ...           ...     ...  ...       ...
# 雪 Distance                         68.0         0.592   0.284    1    -9.398
# 青と夏                                71.0         0.310   0.891    4    -1.660
# 風雨不改 (電影《阿媽有咗第二個》主題曲)              70.0         0.319   0.198    0   -11.611
# 飞鸟和蝉                               67.0         0.578   0.508   10    -8.884
# 麻克與林送夫                             62.0         0.834   0.480    9    -8.529
#
#                        speechiness  acousticness  instrumentalness  liveness  \
# track.name
# #Sarkanbaltsarkanais        0.1040       0.06080          0.000000    0.4030
# 'Til We Meet Again          0.0571       0.13400          0.000000    0.1130
# 00:00                       0.1250       0.64000          0.002270    0.1000
# 0321                        0.0366       0.62500          0.000000    0.1320
# 085 - Ao Vivo               0.0298       0.21100          0.000000    0.9520
# ...                            ...           ...               ...       ...
# 雪 Distance                  0.0319       0.73900          0.000001    0.1730
# 青と夏                         0.0469       0.00157          0.000000    0.2840
# 風雨不改 (電影《阿媽有咗第二個》主題曲)       0.0402       0.94200          0.000009    0.0817
# 飞鸟和蝉                        0.0536       0.72200          0.000000    0.1050
# 麻克與林送夫                      0.0639       0.22400          0.000000    0.1390
#
#                        valence    tempo             artist
# track.name
# #Sarkanbaltsarkanais    0.6260  110.118  Bermudu Divstūris
# 'Til We Meet Again      0.5520  155.710              aespa
# 00:00                   0.3920   95.013           Lartiste
# 0321                    0.0748  171.974            space x
# 085 - Ao Vivo           0.7970  106.031       MC Rogerinho
# ...                        ...      ...                ...
# 雪 Distance              0.6710   99.827             Capper
# 青と夏                     0.7480  184.886   Mrs. GREEN APPLE
# 風雨不改 (電影《阿媽有咗第二個》主題曲)   0.2870   62.925           Keung To
# 飞鸟和蝉                    0.3040  147.940            Ren Ran
# 麻克與林送夫                  0.4980  122.912    Various Artists
#
# [2962 rows x 14 columns]

# %%
columns_names = {'track.album.name': 'album_name', 'track.name': 'track_name', 'track.album.album_type': 'album_type', 'track.popularity':'popularity' }
df.rename(columns=columns_names, inplace=True)

# %%
# Saving the clean dataframe as a csv
df.to_csv('Resources/clean_May_tracks.csv')
